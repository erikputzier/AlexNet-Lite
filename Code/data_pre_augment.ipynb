# %%
#import kagglehub
import os
import random
from PIL import Image, ImageChops, ImageEnhance
import re
import numpy as np
from collections import defaultdict

# Download latest version (Set this to False the first time you are running the script to download the data)
is_downloaded = True

if is_downloaded:
    print("Data is already downloaded")
else:
    path = kagglehub.dataset_download("pinstripezebra/google-streetview-top-50-us-cities")
    print("Path to dataset files:", path)

# Set the directory containing your images (Change this to your directory)
image_folder = r'/Users/maximilianstumpf/Desktop/UCLA/Math156 - Machine Learning/Project/Data/Images'
base_output_folder = r'/Users/maximilianstumpf/Desktop/UCLA/Math156 - Machine Learning/Project/Data/Processed'

# Create the base output directory
os.makedirs(base_output_folder, exist_ok=True)

target_size = (227, 227) # Target size for resized images
max_images_per_city = 5000  # Maximum number of processed images per city
num_patches = 5  # Number of patches to extract per image

# Load the reference "no imagery" image
reference_image_path = r'/Users/maximilianstumpf/Desktop/UCLA/Math156 - Machine Learning/Project/Data/No imagery/No_photo.jpg'
reference_image = Image.open(reference_image_path).convert('L')  # Convert reference to grayscale too

# Statistics tracking with augmentation stats added
processed_stats = defaultdict(lambda: {
    'total': 0, 
    'processed': 0, 
    'augmented': 0,
    'errors': 0,
    'no_imagery': 0
})
# Function to check if an image is "no imagery"
def is_no_imagery_image(img_path, reference_image):
    try:
        img = Image.open(img_path).convert('L') # convert image to grayscale
        img = img.resize(reference_image.size) # resize to match the reference
        diff = ImageChops.difference(reference_image, img) # compute pixel differences
        if diff.getbbox() is None: 
            return True
        img_array = np.array(img)
        std = np.std(img_array)
        return std < 5 # low variance indicates uniform image
    except Exception as e:
        print(f"Error checking no imagery for {img_path}: {e}")
        return False

# Function to extract city name from filename
def get_city_name(filename):
    patterns = [
        r"([A-Za-z]+)(?:_\d+)?(?:_ \([-\d.]+, [-\d.]+\))?\.jpg", # CityName_XYZ.jpg format
        r"([A-Za-z]+[ A-Za-z]+)(?:_\d+)?(?:_ \([-\d.]+, [-\d.]+\))?\.jpg", # Multi-word city names
        r"([A-Za-z]+[.]?[ ]?[A-Za-z]+)(?:_\d+)?(?:_ \([-\d.]+, [-\d.]+\))?\.jpg" # edge cases
    ]
    
    for pattern in patterns:
        match = re.match(pattern, filename)
        if match:
            return match.group(1).replace(" ", "_") # replace spaces with underscores
    return None

# Function to apply augmentations
def apply_augmentations(img):
    augmented_images = []
    
    # List of augmentation functions
    augmentations = [
        ('flip_h', lambda x: x.transpose(Image.FLIP_LEFT_RIGHT)), # horizontal flip
        ('flip_v', lambda x: x.transpose(Image.FLIP_TOP_BOTTOM)), # Vertical flip
        ('rotate90', lambda x: x.rotate(90)), # rotate by 90 degress
        ('bright_up', lambda x: ImageEnhance.Brightness(x).enhance(1.2)), # increase brightness
        ('bright_down', lambda x: ImageEnhance.Brightness(x).enhance(0.8)), # decrease brightness
        ('contrast_up', lambda x: ImageEnhance.Contrast(x).enhance(1.2)), # increase contrast
        ('contrast_down', lambda x: ImageEnhance.Contrast(x).enhance(0.8)) # decrease contrast
    ]
    
    # Apply each augmentation
    for aug_name, aug_func in augmentations:
        try:
            aug_img = aug_func(img)
            augmented_images.append((aug_name, aug_img))
        except Exception as e:
            print(f"Error applying {aug_name} augmentation: {e}")
            continue
    
    return augmented_images

# Function to process and resize image
def process_image(img):
    """Convert image to grayscale and resize"""
    gray_img = img.convert('L')
    return gray_img.resize(target_size)

# Function to extract random crops
def random_crop(img):
    width, height = img.size
    if width < 227 or height < 227:
        raise ValueError("Image size must be at least 227x227 for cropping.")
    
    x = random.randint(0, width - 227)
    y = random.randint(0, height - 227)
    
    return img.crop((x, y, x + 227, y + 227))

# Function to extract random patches and apply augmentation to each patch
def extract_patches(img, num_patches=5):
    patches = []
    gray_img = img if img.mode == 'L' else img.convert('L')
    
    for i in range(num_patches):
        try:
            patch = random_crop(gray_img) # Extract original patch
            patches.append(('original', patch)) # Add original patch with identifier
            augmented_patches = apply_augmentations(patch) # Add augmented versions of the patch
            patches.extend(augmented_patches)
        except ValueError as e:
            print(f"Error extracting patch {i}: {e}")
            continue
            
    return patches

# Group files by city and remove no imagery files
print("\nGrouping files by city and checking for no imagery...")
city_files = defaultdict(list)
for filename in os.listdir(image_folder):
    file_path = os.path.join(image_folder, filename)
    
    if is_no_imagery_image(file_path, reference_image): # skip "no imagery" files
        city_name = get_city_name(filename)
        if city_name:
            processed_stats[city_name]['no_imagery'] += 1
        print(f"Found no imagery file: {filename}")
        continue
        
    city_name = get_city_name(filename)
    if city_name:
        city_files[city_name].append(filename)
        processed_stats[city_name]['total'] += 1

print("\nInitial city statistics:")
for city, stats in processed_stats.items():
    print(f"{city}: {stats['total']} usable images found ({stats['no_imagery']} no imagery files skipped)")

# Process images for each city
print("\nProcessing images with augmentations...")
for city, files in city_files.items():
    print(f"\nProcessing {city}...")
    
    city_output_folder = os.path.join(base_output_folder, city)
    os.makedirs(city_output_folder, exist_ok=True) # create city folder
    
    # Calculate how many original images we need to process
    # Each original image will produce multiple augmented versions
    augmentation_factor = 8  # original + 7 augmentations
    images_per_original = (1 + num_patches) * augmentation_factor
    originals_needed = min(len(files), max_images_per_city // images_per_original)
    
    for filename in files[:originals_needed]:
        file_path = os.path.join(image_folder, filename)
        
        try:
            with Image.open(file_path) as img:
                # Process original image
                processed_img = process_image(img) # resize
                
                # Save original resized version
                resized_output_path = os.path.join(city_output_folder, f"resized_original_{filename}")
                processed_img.save(resized_output_path)
                processed_stats[city]['processed'] += 1
                
                # Save augmented versions of full image
                augmented_images = apply_augmentations(processed_img) # augment resized pic
                for aug_name, aug_img in augmented_images:
                    aug_output_path = os.path.join(city_output_folder, f"resized_{aug_name}_{filename}")
                    aug_img.save(aug_output_path)
                    processed_stats[city]['augmented'] += 1
                
                # Extract and save patches with their augmentations
                try:
                    patches = extract_patches(img, num_patches=num_patches) # extract & augment patches
                    for i, (patch_type, patch) in enumerate(patches):
                        patch_output_path = os.path.join(
                            city_output_folder, 
                            f"patch_{i//augmentation_factor + 1}_{patch_type}_{filename}"
                        )
                        patch.save(patch_output_path)
                        if patch_type == 'original':
                            processed_stats[city]['processed'] += 1
                        else:
                            processed_stats[city]['augmented'] += 1
                            
                    print(f"Successfully processed {filename} for {city} with augmentations")
                except ValueError as e:
                    print(f"Error processing patches for {filename}: {e}")
                    processed_stats[city]['errors'] += 1
                    
        except Exception as e:
            print(f"Error processing {filename}: {e}")
            processed_stats[city]['errors'] += 1

# Print final processing statistics
print("\nFinal Processing Statistics:")
print("-" * 110)
print(f"{'City':<20} {'Original Files':<15} {'No Imagery':<15} {'Processed':<12} {'Augmented':<12} {'Errors':<12}")
print("-" * 110)
for city, stats in processed_stats.items():
    print(f"{city:<20} {stats['total']:<15} {stats['no_imagery']:<15} {stats['processed']:<12} {stats['augmented']:<12} {stats['errors']:<12}")

# Verify final counts
print("\nVerifying final image counts per city...")
for city in city_files.keys():
    city_folder = os.path.join(base_output_folder, city)
    if os.path.exists(city_folder):
        file_count = len(os.listdir(city_folder))
        print(f"{city}: {file_count} total processed files")
    else:
        print(f"Warning: No output folder found for {city}")

print("\nProcessing complete. All images converted to grayscale, augmented, and saved to city-specific folders.")
# Out:
# Data is already downloaded
#
# Grouping files by city and checking for no imagery...
# Found no imagery file: Jacksonvillef_ (30.345588, -81.638109).jpg
# Found no imagery file: Memphis_ (35.090783, -89.992134).jpg
# Found no imagery file: El Paso_ (31.850921, -106.435131).jpg
# Found no imagery file: Tulsa_ (36.121028, -95.875602).jpg
# Found no imagery file: Oklahoma City_ (35.493458, -97.502302).jpg
# Found no imagery file: Nashvillej_ (36.14538, -86.769295).jpg
# Found no imagery file: Denveri_ (39.772808, -104.891637).jpg
# Found no imagery file: El Paso_ (31.840606, -106.43546).jpg
# Found no imagery file: Sacramento_ (38.58537, -121.478973).jpg
# Found no imagery file: Mesa_ (33.417699, -111.743102).jpg
# Found no imagery file: Detroit_ (42.403928, -83.076705).jpg
# Found no imagery file: Tucson_ (32.173772, -110.882009).jpg
# Found no imagery file: Las Vegas_ (36.251718, -115.270892).jpg
# Found no imagery file: Las Vegas_ (36.210536, -115.270495).jpg
# Found no imagery file: San Diego_ (32.697855, -117.1831).jpg
# Found no imagery file: Mesa_ (33.381738, -111.733832).jpg
# Found no imagery file: Louisvillel_ (38.162878, -85.629794).jpg
# Found no imagery file: Louisvillel_ (38.169686, -85.635199).jpg
# Found no imagery file: Louisvillel_ (38.175168, -85.625429).jpg
# Found no imagery file: Los Angeles_ (34.022791, -118.423857).jpg
# Found no imagery file: Miami_ (25.787774, -80.229597).jpg
# Found no imagery file: Oakland_ (37.748586, -122.211887).jpg
# Found no imagery file: Las Vegas_ (36.247236, -115.2835).jpg
# Found no imagery file: Las Vegas_ (36.253616, -115.250771).jpg
# Found no imagery file: Las Vegas_ (36.235678, -115.283296).jpg
# Found no imagery file: Oklahoma City_ (35.45593, -97.505962).jpg
# Found no imagery file: Las Vegas_ (36.206918, -115.270975).jpg
# Found no imagery file: Mesa_ (33.397783, -111.70584).jpg
# Found no imagery file: Mesa_ (33.405373, -111.695115).jpg
# Found no imagery file: Omaha_ (41.272715, -96.074719).jpg
# Found no imagery file: Nashvillej_ (36.190191, -86.786206).jpg
# Found no imagery file: Las Vegas_ (36.212137, -115.270672).jpg
# Found no imagery file: Raleigh_ (35.808183, -78.641781).jpg
# Found no imagery file: Las Vegas_ (36.242489, -115.270872).jpg
# Found no imagery file: Phoenix_ (33.558007, -112.10617).jpg
# Found no imagery file: Tucson_ (32.126565, -110.849653).jpg
# Found no imagery file: Denveri_ (39.777195, -104.875552).jpg
# Found no imagery file: San Diego_ (32.694417, -117.150864).jpg
# Found no imagery file: San Jose_ (37.339953, -121.910078).jpg
# Found no imagery file: Oakland_ (37.753034, -122.205673).jpg
# Found no imagery file: Denveri_ (39.760461, -104.855958).jpg
# Found no imagery file: Tucson_ (32.137433, -110.853549).jpg
# Found no imagery file: Mesa_ (33.390188, -111.734062).jpg
# Found no imagery file: Boston_ (42.316267, -71.005192).jpg
# Found no imagery file: Louisvillel_ (38.16363, -85.630579).jpg
# Found no imagery file: Los Angeles_ (34.044372, -118.417347).jpg
# Found no imagery file: Albuquerque_ (35.108564, -106.664419).jpg
# Found no imagery file: Tucson_ (32.163243, -110.870117).jpg
# Found no imagery file: Tucson_ (32.173889, -110.859793).jpg
# Found no imagery file: Mesa_ (33.388284, -111.703324).jpg
# Found no imagery file: Las Vegas_ (36.224686, -115.27399).jpg
# Found no imagery file: Bakersfield_ (35.351876, -119.025003).jpg
# Found no imagery file: Mesa_ (33.41264, -111.728375).jpg
# Found no imagery file: Tampa_ (27.993622, -82.467055).jpg
# Found no imagery file: Chicago_ (41.858493, -87.689759).jpg
# Found no imagery file: Mesa_ (33.392034, -111.733322).jpg
# Found no imagery file: Omaha_ (41.266429, -96.055421).jpg
# Found no imagery file: Virginia Beachm_ (36.798011, -76.037268).jpg
# Found no imagery file: Las Vegas_ (36.252267, -115.23881).jpg
# Found no imagery file: Omaha_ (41.235816, -96.031102).jpg
# Found no imagery file: Mesa_ (33.388288, -111.734776).jpg
# Found no imagery file: Louisvillel_ (38.185129, -85.627127).jpg
# Found no imagery file: Long Beach_ (33.795435, -118.163854).jpg
# Found no imagery file: San Diego_ (32.729868, -117.18377).jpg
# Found no imagery file: Las Vegas_ (36.213957, -115.27466).jpg
# Found no imagery file: Fort Worth_ (32.778355, -97.329605).jpg
# Found no imagery file: Long Beach_ (33.793072, -118.150417).jpg
# Found no imagery file: Denveri_ (39.771849, -104.892461).jpg
# Found no imagery file: Chicago_ (41.827793, -87.685647).jpg
# Found no imagery file: Albuquerque_ (35.124976, -106.661505).jpg
# Found no imagery file: Atlanta_ (33.741371, -84.405454).jpg
# Found no imagery file: Denveri_ (39.784515, -104.874241).jpg
# Found no imagery file: Chicago_ (41.834368, -87.701495).jpg
# Found no imagery file: San Diego_ (32.696445, -117.151898).jpg
# Found no imagery file: Las Vegas_ (36.207753, -115.266481).jpg
# Found no imagery file: Philadelphiae_ (40.022858, -75.142079).jpg
# Found no imagery file: Tucson_ (32.127165, -110.847372).jpg
# Found no imagery file: Mesa_ (33.403234, -111.707487).jpg
# Found no imagery file: Colorado Springs_ (38.880059, -104.765572).jpg
# Found no imagery file: Chicago_ (41.851274, -87.663799).jpg
# Found no imagery file: Tucson_ (32.135206, -110.863084).jpg
# Found no imagery file: Tucson_ (32.170932, -110.878144).jpg
# Found no imagery file: San Jose_ (37.350834, -121.914639).jpg
# Found no imagery file: Chicago_ (41.834411, -87.698557).jpg
# Found no imagery file: Bakersfield_ (35.356051, -119.045081).jpg
# Found no imagery file: Albuquerque_ (35.08899, -106.672331).jpg
# Found no imagery file: Indianapolisg_ (39.792746, -86.174996).jpg
# Found no imagery file: Las Vegas_ (36.235637, -115.28065).jpg
# Found no imagery file: Kansas City_ (39.142586, -94.556914).jpg
# Found no imagery file: Chicago_ (41.859392, -87.692212).jpg
# Found no imagery file: Phoenix_ (33.55681, -112.105682).jpg
# Found no imagery file: Wichita_ (37.673995, -97.348373).jpg
# Found no imagery file: Memphis_ (35.121755, -89.961207).jpg
# Found no imagery file: Boston_ (42.340365, -71.029605).jpg
# Found no imagery file: El Paso_ (31.840532, -106.450349).jpg
# Found no imagery file: Nashvillej_ (36.175168, -86.778093).jpg
# Found no imagery file: Kansas City_ (39.138402, -94.551964).jpg
# Found no imagery file: Memphis_ (35.08741, -89.989729).jpg
# Found no imagery file: Las Vegas_ (36.206058, -115.266381).jpg
# Found no imagery file: Kansas City_ (39.123077, -94.575331).jpg
# Found no imagery file: Columbus_ (39.974766, -82.988926).jpg
# Found no imagery file: Mesa_ (33.37629, -111.728358).jpg
# Found no imagery file: Houston_ (29.794986, -95.370087).jpg
# Found no imagery file: Houston_ (29.776362, -95.371184).jpg
# Found no imagery file: Louisvillel_ (38.169894, -85.635836).jpg
# Found no imagery file: Nashvillej_ (36.177668, -86.778194).jpg
# Found no imagery file: Nashvillej_ (36.186809, -86.79894).jpg
# Found no imagery file: El Paso_ (31.845208, -106.435944).jpg
# Found no imagery file: Phoenix_ (33.577142, -112.068555).jpg
# Found no imagery file: Omaha_ (41.272508, -96.064884).jpg
# Found no imagery file: Albuquerque_ (35.109715, -106.666876).jpg
# Found no imagery file: Chicago_ (41.861493, -87.677182).jpg
# Found no imagery file: Albuquerque_ (35.11319, -106.635383).jpg
# Found no imagery file: Bakersfield_ (35.372416, -119.041371).jpg
# Found no imagery file: Las Vegas_ (36.212356, -115.270243).jpg
# Found no imagery file: Tucson_ (32.125434, -110.879265).jpg
# Found no imagery file: Long Beach_ (33.800242, -118.163472).jpg
# Found no imagery file: El Paso_ (31.857977, -106.43322).jpg
# Found no imagery file: Memphis_ (35.097421, -89.96454).jpg
# Found no imagery file: Chicago_ (41.850528, -87.661136).jpg
# Found no imagery file: Mesa_ (33.392189, -111.723592).jpg
# Found no imagery file: Milwaukee_ (43.079914, -87.990544).jpg
# Found no imagery file: Detroit_ (42.358092, -83.085708).jpg
# Found no imagery file: Denveri_ (39.7737, -104.892732).jpg
# Found no imagery file: Tucson_ (32.173429, -110.882846).jpg
# Found no imagery file: Sacramento_ (38.593976, -121.46321).jpg
# Found no imagery file: San Jose_ (37.353071, -121.872246).jpg
# Found no imagery file: Mesa_ (33.399197, -111.706296).jpg
# Found no imagery file: Virginia Beachm_ (36.799982, -76.00855).jpg
# Found no imagery file: Austin_ (30.314115, -97.728381).jpg
# Found no imagery file: Las Vegas_ (36.237639, -115.254335).jpg
# Found no imagery file: Chicago_ (41.838307, -87.68298).jpg
# Found no imagery file: Phoenix_ (33.561883, -112.104385).jpg
# Found no imagery file: Phoenix_ (33.568436, -112.086635).jpg
# Found no imagery file: Louisvillel_ (38.175386, -85.635991).jpg
# Found no imagery file: Chicago_ (41.835448, -87.66236).jpg
# Found no imagery file: Chicago_ (41.839517, -87.676685).jpg
# Found no imagery file: Atlanta_ (33.779935, -84.421699).jpg
# Found no imagery file: Mesa_ (33.397341, -111.734736).jpg
# Found no imagery file: San Jose_ (37.364681, -121.887159).jpg
# Found no imagery file: Tucson_ (32.168098, -110.874372).jpg
# Found no imagery file: Indianapolisg_ (39.75939, -86.173265).jpg
# Found no imagery file: Boston_ (42.340246, -71.029328).jpg
# Found no imagery file: Atlanta_ (33.773864, -84.433799).jpg
# Found no imagery file: Chicago_ (41.843864, -87.669609).jpg
# Found no imagery file: Tucson_ (32.135888, -110.847538).jpg
# Found no imagery file: Oakland_ (37.749524, -122.238713).jpg
# Found no imagery file: Memphis_ (35.133265, -89.983735).jpg
# Found no imagery file: Raleigh_ (35.815252, -78.633187).jpg
# Found no imagery file: Columbus_ (39.977501, -82.996855).jpg
# Found no imagery file: Long Beach_ (33.799236, -118.162418).jpg
# Found no imagery file: Tucson_ (32.163923, -110.84828).jpg
# Found no imagery file: Colorado Springs_ (38.861316, -104.783403).jpg
# Found no imagery file: Mesa_ (33.405775, -111.704621).jpg
# Found no imagery file: Detroit_ (42.363603, -83.078185).jpg
# Found no imagery file: San Jose_ (37.356914, -121.868097).jpg
# Found no imagery file: Phoenix_ (33.593576, -112.088125).jpg
# Found no imagery file: Louisvillel_ (38.187383, -85.628042).jpg
# Found no imagery file: Phoenix_ (33.586658, -112.082301).jpg
# Found no imagery file: Virginia Beachm_ (36.804917, -76.006999).jpg
# Found no imagery file: Tampa_ (27.994146, -82.466398).jpg
# Found no imagery file: Houston_ (29.776724, -95.370256).jpg
# Found no imagery file: Mesa_ (33.399286, -111.704053).jpg
# Found no imagery file: Bakersfield_ (35.335597, -119.039687).jpg
# Found no imagery file: Boston_ (42.31873, -71.004756).jpg
# Found no imagery file: Mesa_ (33.410863, -111.739139).jpg
# Found no imagery file: Detroit_ (42.369738, -83.088516).jpg
# Found no imagery file: Boston_ (42.318809, -71.008949).jpg
# Found no imagery file: Virginia Beachm_ (36.792767, -76.051491).jpg
# Found no imagery file: Raleigh_ (35.832649, -78.626188).jpg
# Found no imagery file: Chicago_ (41.85691, -87.686953).jpg
# Found no imagery file: San Diego_ (32.732168, -117.136061).jpg
# Found no imagery file: Denveri_ (39.775876, -104.887274).jpg
# Found no imagery file: Denveri_ (39.775573, -104.876323).jpg
# Found no imagery file: Tucson_ (32.171408, -110.8751).jpg
# Found no imagery file: Las Vegas_ (36.224555, -115.274994).jpg
# Found no imagery file: Las Vegas_ (36.247617, -115.276664).jpg
# Found no imagery file: Chicago_ (41.822458, -87.660139).jpg
# Found no imagery file: Indianapolisg_ (39.75794, -86.150657).jpg
# Found no imagery file: Portland_ (45.523671, -122.662334).jpg
# Found no imagery file: Omaha_ (41.249209, -96.025841).jpg
# Found no imagery file: Atlanta_ (33.778345, -84.422214).jpg
# Found no imagery file: Indianapolisg_ (39.766431, -86.137746).jpg
# Found no imagery file: Chicago_ (41.821273, -87.672191).jpg
# Found no imagery file: Phoenix_ (33.572443, -112.109886).jpg
# Found no imagery file: Colorado Springs_ (38.861008, -104.755738).jpg
# Found no imagery file: Columbus_ (40.004778, -83.014333).jpg
# Found no imagery file: Louisvillel_ (38.17281, -85.64989).jpg
# Found no imagery file: Indianapolisg_ (39.755442, -86.153928).jpg
# Found no imagery file: Chicago_ (41.840492, -87.681595).jpg
# Found no imagery file: Indianapolisg_ (39.794088, -86.157568).jpg
# Found no imagery file: Tucson_ (32.12836, -110.853378).jpg
# Found no imagery file: Minneapolis_ (44.976669, -93.285391).jpg
# Found no imagery file: Atlanta_ (33.753477, -84.408377).jpg
# Found no imagery file: Oklahoma City_ (35.467317, -97.503118).jpg
# Found no imagery file: Virginia Beachm_ (36.803139, -76.03546).jpg
# Found no imagery file: Phoenix_ (33.568377, -112.10765).jpg
# Found no imagery file: Tucson_ (32.164837, -110.871115).jpg
# Found no imagery file: El Paso_ (31.826467, -106.439325).jpg
# Found no imagery file: Denveri_ (39.778481, -104.897068).jpg
# Found no imagery file: Tucson_ (32.15791, -110.894474).jpg
# Found no imagery file: Boston_ (42.317318, -71.005799).jpg
# Found no imagery file: Boston_ (42.316085, -71.005655).jpg
# Found no imagery file: Minneapolis_ (44.981144, -93.252638).jpg
# Found no imagery file: Austin_ (30.312935, -97.758599).jpg
# Found no imagery file: Kansas City_ (39.141871, -94.557873).jpg
# Found no imagery file: Oakland_ (37.764146, -122.212739).jpg
# Found no imagery file: Las Vegas_ (36.239584, -115.26199).jpg
# Found no imagery file: Jacksonvillef_ (30.351285, -81.66608).jpg
# Found no imagery file: Boston_ (42.36042, -71.025094).jpg
# Found no imagery file: Indianapolisg_ (39.784886, -86.125149).jpg
# Found no imagery file: Las Vegas_ (36.249142, -115.240664).jpg
# Found no imagery file: Mesa_ (33.408317, -111.700685).jpg
# Found no imagery file: Las Vegas_ (36.226252, -115.245788).jpg
# Found no imagery file: Las Vegas_ (36.208429, -115.268481).jpg
# Found no imagery file: Philadelphiae_ (40.008209, -75.121944).jpg
# Found no imagery file: Indianapolisg_ (39.759306, -86.17233).jpg
# Found no imagery file: Indianapolisg_ (39.797088, -86.171027).jpg
# Found no imagery file: Tucson_ (32.154576, -110.859711).jpg
# Found no imagery file: Tucson_ (32.13588, -110.852418).jpg
# Found no imagery file: Atlanta_ (33.77913, -84.424304).jpg
# Found no imagery file: Las Vegas_ (36.208943, -115.265669).jpg
# Found no imagery file: El Paso_ (31.867324, -106.409724).jpg
# Found no imagery file: Virginia Beachm_ (36.789179, -76.054105).jpg
# Found no imagery file: Las Vegas_ (36.247863, -115.240237).jpg
# Found no imagery file: Mesa_ (33.409678, -111.740965).jpg
# Found no imagery file: Mesa_ (33.390414, -111.732337).jpg
# Found no imagery file: Omaha_ (41.242278, -96.069109).jpg
# Found no imagery file: Mesa_ (33.407745, -111.709542).jpg
# Found no imagery file: Wichita_ (37.67336, -97.347064).jpg
# Found no imagery file: Austin_ (30.315261, -97.727836).jpg
# Found no imagery file: Detroit_ (42.401401, -83.119287).jpg
# Found no imagery file: Las Vegas_ (36.242039, -115.268145).jpg
# Found no imagery file: Raleigh_ (35.805937, -78.639046).jpg
# Found no imagery file: Indianapolisg_ (39.760547, -86.172589).jpg
# Found no imagery file: Atlanta_ (33.767946, -84.423878).jpg
# Found no imagery file: Jacksonvillef_ (30.351857, -81.659944).jpg
# Found no imagery file: Omaha_ (41.275934, -96.036555).jpg
# Found no imagery file: Tucson_ (32.132785, -110.87815).jpg
# Found no imagery file: Fresno_ (36.756218, -119.774278).jpg
# Found no imagery file: Baltimorem_ (39.303487, -76.60475).jpg
# Found no imagery file: Tucson_ (32.165914, -110.873065).jpg
# Found no imagery file: Atlanta_ (33.783305, -84.41397).jpg
# Found no imagery file: Albuquerque_ (35.08809, -106.67245).jpg
# Found no imagery file: Tucson_ (32.1323, -110.863951).jpg
# Found no imagery file: Colorado Springs_ (38.858999, -104.739952).jpg
# Found no imagery file: Sacramento_ (38.556115, -121.481358).jpg
# Found no imagery file: Austin_ (30.320391, -97.77456).jpg
# Found no imagery file: Indianapolisg_ (39.792413, -86.171251).jpg
# Found no imagery file: Denveri_ (39.775422, -104.883724).jpg
# Found no imagery file: El Paso_ (31.838817, -106.435044).jpg
# Found no imagery file: Chicago_ (41.83826, -87.678522).jpg
# Found no imagery file: Chicago_ (41.818568, -87.676212).jpg
# Found no imagery file: Las Vegas_ (36.243589, -115.270401).jpg
# Found no imagery file: Las Vegas_ (36.242917, -115.275663).jpg
# Found no imagery file: Chicago_ (41.820076, -87.676295).jpg
# Found no imagery file: Chicago_ (41.82006, -87.680254).jpg
# Found no imagery file: Dallas_ (32.808159, -96.776131).jpg
# Found no imagery file: Chicago_ (41.83169, -87.703405).jpg
# Found no imagery file: Mesa_ (33.403817, -111.723455).jpg
# Found no imagery file: Jacksonvillef_ (30.315885, -81.648922).jpg
# Found no imagery file: Las Vegas_ (36.243922, -115.280022).jpg
# Found no imagery file: San Jose_ (37.361336, -121.873149).jpg
# Found no imagery file: Nashvillej_ (36.183589, -86.779608).jpg
# Found no imagery file: Mesa_ (33.405186, -111.706556).jpg
# Found no imagery file: Phoenix_ (33.568082, -112.070222).jpg
# Found no imagery file: Austin_ (30.322825, -97.758854).jpg
# Found no imagery file: Nashvillej_ (36.154785, -86.812003).jpg
# Found no imagery file: Tucson_ (32.14483, -110.846407).jpg
# Found no imagery file: Kansas City_ (39.133149, -94.556036).jpg
# Found no imagery file: Omaha_ (41.247909, -96.048622).jpg
# Found no imagery file: Columbus_ (39.994684, -82.988571).jpg
# Found no imagery file: San Diego_ (32.701921, -117.155324).jpg
# Found no imagery file: Indianapolisg_ (39.792072, -86.136711).jpg
# Found no imagery file: Tucson_ (32.144906, -110.888644).jpg
# Found no imagery file: Denveri_ (39.782693, -104.881723).jpg
# Found no imagery file: Nashvillej_ (36.186411, -86.799019).jpg
# Found no imagery file: Houston_ (29.777132, -95.401268).jpg
# Found no imagery file: Mesa_ (33.39161, -111.729258).jpg
# Found no imagery file: Tucson_ (32.174004, -110.881158).jpg
# Found no imagery file: Omaha_ (41.272454, -96.073997).jpg
# Found no imagery file: Chicago_ (41.834233, -87.694656).jpg
# Found no imagery file: El Paso_ (31.842062, -106.454812).jpg
# Found no imagery file: Miami_ (25.785857, -80.218083).jpg
# Found no imagery file: Los Angeles_ (34.044674, -118.413291).jpg
# Found no imagery file: Fort Worth_ (32.777161, -97.332245).jpg
# Found no imagery file: Boston_ (42.318386, -71.007282).jpg
# Found no imagery file: Jacksonvillef_ (30.324463, -81.668567).jpg
# Found no imagery file: Mesa_ (33.424701, -111.703084).jpg
# Found no imagery file: Mesa_ (33.411093, -111.741399).jpg
# Found no imagery file: Fresno_ (36.786047, -119.769514).jpg
# Found no imagery file: Raleigh_ (35.842711, -78.641583).jpg
# Found no imagery file: Austin_ (30.319974, -97.758814).jpg
# Found no imagery file: Louisvillel_ (38.168867, -85.63991).jpg
# Found no imagery file: Tulsa_ (36.134592, -95.89101).jpg
# Found no imagery file: Mesa_ (33.376212, -111.744686).jpg
# Found no imagery file: Mesa_ (33.38296, -111.699698).jpg
# Found no imagery file: Mesa_ (33.416465, -111.734168).jpg
# Found no imagery file: Phoenix_ (33.578, -112.067307).jpg
# Found no imagery file: Minneapolis_ (44.942369, -93.258118).jpg
# Found no imagery file: Oakland_ (37.774922, -122.246865).jpg
# Found no imagery file: Chicago_ (41.840181, -87.680555).jpg
# Found no imagery file: Colorado Springs_ (38.879129, -104.763013).jpg
# Found no imagery file: Chicago_ (41.833438, -87.661124).jpg
# Found no imagery file: Austin_ (30.312709, -97.764898).jpg
# Found no imagery file: Memphis_ (35.122609, -89.964532).jpg
# Found no imagery file: Jacksonvillef_ (30.321985, -81.654649).jpg
# Found no imagery file: Omaha_ (41.268751, -96.039761).jpg
# Found no imagery file: Nashvillej_ (36.181357, -86.777137).jpg
# Found no imagery file: El Paso_ (31.83952, -106.434937).jpg
# Found no imagery file: Omaha_ (41.239068, -96.071495).jpg
# Found no imagery file: Denveri_ (39.776593, -104.898711).jpg
# Found no imagery file: Mesa_ (33.399587, -111.707269).jpg
# Found no imagery file: El Paso_ (31.833867, -106.437164).jpg
# Found no imagery file: Nashvillej_ (36.190082, -86.802882).jpg
# Found no imagery file: Phoenix_ (33.550348, -112.093451).jpg
# Found no imagery file: Omaha_ (41.247383, -96.050842).jpg
# Found no imagery file: Kansas City_ (39.141703, -94.55662).jpg
# Found no imagery file: Omaha_ (41.237228, -96.036792).jpg
# Found no imagery file: Louisvillel_ (38.17621, -85.631714).jpg
# Found no imagery file: Indianapolisg_ (39.763121, -86.147408).jpg
# Found no imagery file: Mesa_ (33.399678, -111.701708).jpg
# Found no imagery file: Albuquerque_ (35.094109, -106.633547).jpg
# Found no imagery file: Nashvillej_ (36.177781, -86.794096).jpg
# Found no imagery file: Mesa_ (33.416826, -111.734205).jpg
#
# Initial city statistics:
# San_Franciscoh: 193 usable images found (1 no imagery files skipped)
# Chicago: 165 usable images found (25 no imagery files skipped)
# Baltimorem: 101 usable images found (1 no imagery files skipped)
# Sacramento: 176 usable images found (3 no imagery files skipped)
# Jacksonvillef: 171 usable images found (7 no imagery files skipped)
# Austin: 177 usable images found (8 no imagery files skipped)
# Memphis: 179 usable images found (8 no imagery files skipped)
# Phoenix: 165 usable images found (15 no imagery files skipped)
# Detroit: 177 usable images found (6 no imagery files skipped)
# Minneapolis: 193 usable images found (3 no imagery files skipped)
# Omaha: 179 usable images found (14 no imagery files skipped)
# Kansas_City: 169 usable images found (8 no imagery files skipped)
# Colorado_Springs: 162 usable images found (6 no imagery files skipped)
# Indianapolisg: 185 usable images found (13 no imagery files skipped)
# Charlotte: 191 usable images found (0 no imagery files skipped)
# Las_Vegas: 163 usable images found (32 no imagery files skipped)
# Seattle: 176 usable images found (0 no imagery files skipped)
# San_Antonio: 198 usable images found (1 no imagery files skipped)
# Wichita: 157 usable images found (2 no imagery files skipped)
# Long_Beach: 163 usable images found (5 no imagery files skipped)
# Los_Angeles: 185 usable images found (4 no imagery files skipped)
# Oklahoma_City: 169 usable images found (4 no imagery files skipped)
# Bakersfield: 180 usable images found (4 no imagery files skipped)
# Portland: 193 usable images found (1 no imagery files skipped)
# Oakland: 147 usable images found (5 no imagery files skipped)
# Dallas: 188 usable images found (1 no imagery files skipped)
# Philadelphiae: 193 usable images found (3 no imagery files skipped)
# Mesa: 111 usable images found (34 no imagery files skipped)
# Denveri: 171 usable images found (14 no imagery files skipped)
# Houston: 187 usable images found (4 no imagery files skipped)
# San_Jose: 185 usable images found (10 no imagery files skipped)
# Raleigh: 188 usable images found (8 no imagery files skipped)
# Albuquerque: 170 usable images found (9 no imagery files skipped)
# Columbus: 186 usable images found (4 no imagery files skipped)
# Milwaukee: 189 usable images found (2 no imagery files skipped)
# El_Paso: 93 usable images found (12 no imagery files skipped)
# Louisvillel: 140 usable images found (13 no imagery files skipped)
# Atlanta: 175 usable images found (9 no imagery files skipped)
# Fresno: 155 usable images found (3 no imagery files skipped)
# Tulsa: 170 usable images found (2 no imagery files skipped)
# Nashvillej: 171 usable images found (14 no imagery files skipped)
# New_Yorkd: 190 usable images found (0 no imagery files skipped)
# Fort_Worth: 136 usable images found (2 no imagery files skipped)
# Tampa: 194 usable images found (2 no imagery files skipped)
# Miami: 192 usable images found (2 no imagery files skipped)
# Tucson: 54 usable images found (26 no imagery files skipped)
# Washingtonk: 82 usable images found (0 no imagery files skipped)
# Boston: 62 usable images found (9 no imagery files skipped)
# San_Diego: 124 usable images found (7 no imagery files skipped)
# Virginia_Beachm: 8 usable images found (7 no imagery files skipped)
#
# Processing images with augmentations...
#
# Processing San_Franciscoh...
# Successfully processed San Franciscoh_ (37.763729, -122.447069).jpg for San_Franciscoh with augmentations
# Successfully processed San Franciscoh_ (37.763625, -122.447764).jpg for San_Franciscoh with augmentations
# Successfully processed San Franciscoh_ (37.762674, -122.412046).jpg for San_Franciscoh with augmentations
# Successfully processed San Franciscoh_ (37.774991, -122.420157).jpg for San_Franciscoh with augmentations
# Successfully processed San Franciscoh_ (37.804283, -122.429126).jpg for San_Franciscoh with augmentations
# Successfully processed San Franciscoh_ (37
# Indianapolisg        185             13              624          4368         0
# Charlotte            191             0               624          4368         0
# Las_Vegas            163             32              624          4368         0
# Seattle              176             0               624          4368         0
# San_Antonio          198             1               624          4368         0
# Wichita              157             2               624          4368         0
# Long_Beach           163             5               624          4368         0
# Los_Angeles          185             4               624          4368         0
# Oklahoma_City        169             4               624          4368         0
# Bakersfield          180             4               624          4368         0
# Portland             193             1               624          4368         0
# Oakland              147             5               624          4368         0
# Dallas               188             1               624          4368         0
# Philadelphiae        193             3               624          4368         0
# Mesa                 111             34              624          4368         0
# Denveri              171             14              624          4368         0
# Houston              187             4               624          4368         0
# San_Jose             185             10              624          4368         0
# Raleigh              188             8               624          4368         0
# Albuquerque          170             9               624          4368         0
# Columbus             186             4               624          4368         0
# Milwaukee            189             2               624          4368         0
# El_Paso              93              12              558          3906         0
# Louisvillel          140             13              624          4368         0
# Atlanta              175             9               624          4368         0
# Fresno               155             3               624          4368         0
# Tulsa                170             2               624          4368         0
# Nashvillej           171             14              624          4368         0
# New_Yorkd            190             0               624          4368         0
# Fort_Worth           136             2               624          4368         0
# Tampa                194             2               624          4368         0
# Miami                192             2               624          4368         0
# Tucson               54              26              324          2268         0
# Washingtonk          82              0               492          3444         0
# Boston               62              9               372          2604         0
# San_Diego            124             7               624          4368         0
# Virginia_Beachm      8               7               48           336          0
#
# Verifying final image counts per city...
# San_Franciscoh: 4992 total processed files
# Chicago: 4992 total processed files
# Baltimorem: 4848 total processed files
# Sacramento: 4992 total processed files
# Austin: 4992 total processed files
# Memphis: 4992 total processed files
# Phoenix: 4992 total processed files
# Detroit: 4992 total processed files
# Minneapolis: 4992 total processed files
# Omaha: 4992 total processed files
# Kansas_City: 4992 total processed files
# Colorado_Springs: 4992 total processed files
# Indianapolisg: 4992 total processed files
# Charlotte: 4992 total processed files
# Las_Vegas: 4992 total processed files
# Seattle: 4992 total processed files
# San_Antonio: 4992 total processed files
# Wichita: 4992 total processed files
# Long_Beach: 4992 total processed files
# Los_Angeles: 4992 total processed files
# Oklahoma_City: 4992 total processed files
# Bakersfield: 4992 total processed files
# Portland: 4992 total processed files
# Oakland: 4992 total processed files
# Dallas: 4992 total processed files
# Philadelphiae: 4992 total processed files
# Mesa: 4992 total processed files
# Denveri: 4992 total processed files
# Jacksonvillef: 4992 total processed files
# Houston: 4992 total processed files
# San_Jose: 4992 total processed files
# Raleigh: 4992 total processed files
# Albuquerque: 4992 total processed files
# Columbus: 4992 total processed files
# Milwaukee: 4992 total processed files
# Louisvillel: 4992 total processed files
# Atlanta: 4992 total processed files
# Fresno: 4992 total processed files
# Nashvillej: 4992 total processed files
# New_Yorkd: 4992 total processed files
# Fort_Worth: 4992 total processed files
# Tampa: 4992 total processed files
# Tulsa: 4992 total processed files
# Miami: 4992 total processed files
# Tucson: 2592 total processed files
# Washingtonk: 3936 total processed files
# Boston: 2976 total processed files
# San_Diego: 4992 total processed files
# El_Paso: 4464 total processed files
# Virginia_Beachm: 384 total processed files
#
# Processing complete. All images converted to grayscale, augmented, and saved to city-specific folders.
