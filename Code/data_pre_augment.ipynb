# %%
import os
import random
from PIL import Image, ImageChops, ImageEnhance
import numpy as np
from collections import defaultdict
from albumentations import Compose, RandomCrop, HorizontalFlip, RandomBrightnessContrast, ShiftScaleRotate, GaussNoise

# Set the directory containing your images
image_folder = r'/Users/maximilianstumpf/Desktop/UCLA/Math156 - Machine Learning/Project/Data/Images'
base_output_folder = r'/Users/maximilianstumpf/Desktop/UCLA/Math156 - Machine Learning/Project/Data/Processed'

# Create the base output directory
os.makedirs(base_output_folder, exist_ok=True)

target_size = (227, 227)  # Target size for resized images
max_images_per_city = 5000  # Maximum number of processed images per city

# Load the reference "no imagery" image
reference_image_path = r'/Users/maximilianstumpf/Desktop/UCLA/Math156 - Machine Learning/Project/Data/No imagery/No_photo.jpg'
reference_image = Image.open(reference_image_path).convert('L')  # Convert reference to grayscale

# Statistics tracking
processed_stats = defaultdict(lambda: {
    'total': 0,
    'processed': 0,
    'augmented': 0,
    'errors': 0,
    'no_imagery': 0
})


# Function to check if an image is "no imagery"
def is_no_imagery_image(img_path, reference_image):
    try:
        img = Image.open(img_path).convert('L')  # Convert image to grayscale
        img = img.resize(reference_image.size)  # Resize to match the reference
        diff = ImageChops.difference(reference_image, img)  # Compute pixel differences
        if diff.getbbox() is None:
            return True
        img_array = np.array(img)
        std = np.std(img_array)
        return std < 5  # Low variance indicates uniform image
    except Exception as e:
        print(f"Error checking no imagery for {img_path}: {e}")
        return False


# Function to apply augmentations using Albumentations
def apply_augmentations_with_albumentations(img):
    aug = Compose([
        HorizontalFlip(p=0.5),  # Flip horizontally
        RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5),  # Adjust brightness and contrast
        ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=30, p=0.5),  # Random shifts, scaling, rotation
        GaussNoise(var_limit=(10.0, 50.0), p=0.3)  # Add random noise
    ])
    
    img_array = np.array(img)
    augmented = aug(image=img_array)
    return Image.fromarray(augmented["image"])


# Function to process and resize image
def process_image(img):
    """Convert image to grayscale and resize"""
    gray_img = img.convert("L")
    return gray_img.resize(target_size)


# Group files by city and remove "no imagery" files
print("\nGrouping files by city and checking for 'no imagery'...")
city_files = defaultdict(list)
for filename in os.listdir(image_folder):
    file_path = os.path.join(image_folder, filename)

    if is_no_imagery_image(file_path, reference_image):  # Skip "no imagery" files
        city_name = filename.split("_")[0]  # Simple city extraction
        processed_stats[city_name]['no_imagery'] += 1
        continue

    city_name = filename.split("_")[0]  # Extract city name
    if city_name:
        city_files[city_name].append(filename)
        processed_stats[city_name]['total'] += 1

print("\nInitial city statistics:")
for city, stats in processed_stats.items():
    print(f"{city}: {stats['total']} usable images found ({stats['no_imagery']} 'no imagery' files skipped)")


# Process images for each city
print("\nProcessing images with augmentations...")
for city, files in city_files.items():
    print(f"\nProcessing {city}...")
    
    city_output_folder = os.path.join(base_output_folder, city)
    os.makedirs(city_output_folder, exist_ok=True)  # Create city folder

    originals_needed = min(len(files), max_images_per_city)

    for filename in files[:originals_needed]:
        file_path = os.path.join(image_folder, filename)

        try:
            with Image.open(file_path) as img:
                # Process original image
                resized_img = process_image(img)  # Resize
                resized_output_path = os.path.join(city_output_folder, f"resized_{filename}")
                resized_img.save(resized_output_path)
                processed_stats[city]['processed'] += 1

                # Apply augmentations
                for i in range(8):  # Generate up to 8 augmented images
                    try:
                        augmented_img = apply_augmentations_with_albumentations(resized_img)
                        aug_output_path = os.path.join(city_output_folder, f"aug_{i}_{filename}")
                        augmented_img.save(aug_output_path)
                        processed_stats[city]['augmented'] += 1
                    except Exception as e:
                        print(f"Error augmenting {filename}: {e}")
                        processed_stats[city]['errors'] += 1

        except Exception as e:
            print(f"Error processing {filename}: {e}")
            processed_stats[city]['errors'] += 1


# Print final processing statistics
print("\nFinal Processing Statistics:")
print("-" * 100)
print(f"{'City':<20} {'Original Files':<15} {'No Imagery':<15} {'Processed':<12} {'Augmented':<12} {'Errors':<12}")
print("-" * 100)
for city, stats in processed_stats.items():
    print(f"{city:<20} {stats['total']:<15} {stats['no_imagery']:<15} {stats['processed']:<12} {stats['augmented']:<12} {stats['errors']:<12}")

# Verify final counts
print("\nVerifying final image counts per city...")
for city in city_files.keys():
    city_folder = os.path.join(base_output_folder, city)
    if os.path.exists(city_folder):
        file_count = len(os.listdir(city_folder))
        print(f"{city}: {file_count} total processed files")
    else:
        print(f"Warning: No output folder found for {city}")

print("\nProcessing complete. All images converted, augmented, and saved to city-specific folders.")
# Out:
# Grouping files by city and checking for 'no imagery'...
#
# Initial city statistics:
# San Franciscoh: 193 usable images found (1 'no imagery' files skipped)
# Chicago: 165 usable images found (25 'no imagery' files skipped)
# Baltimorem: 101 usable images found (1 'no imagery' files skipped)
# Sacramento: 176 usable images found (3 'no imagery' files skipped)
# Jacksonvillef: 171 usable images found (7 'no imagery' files skipped)
# Austin: 177 usable images found (8 'no imagery' files skipped)
# Memphis: 179 usable images found (8 'no imagery' files skipped)
# Phoenix: 165 usable images found (15 'no imagery' files skipped)
# Detroit: 177 usable images found (6 'no imagery' files skipped)
# Minneapolis: 193 usable images found (3 'no imagery' files skipped)
# Omaha: 179 usable images found (14 'no imagery' files skipped)
# Kansas City: 169 usable images found (8 'no imagery' files skipped)
# Colorado Springs: 162 usable images found (6 'no imagery' files skipped)
# Indianapolisg: 185 usable images found (13 'no imagery' files skipped)
# Charlotte: 191 usable images found (0 'no imagery' files skipped)
# Las Vegas: 163 usable images found (32 'no imagery' files skipped)
# Seattle: 176 usable images found (0 'no imagery' files skipped)
# San Antonio: 198 usable images found (1 'no imagery' files skipped)
# Wichita: 157 usable images found (2 'no imagery' files skipped)
# Long Beach: 163 usable images found (5 'no imagery' files skipped)
# Los Angeles: 185 usable images found (4 'no imagery' files skipped)
# Oklahoma City: 169 usable images found (4 'no imagery' files skipped)
# Bakersfield: 180 usable images found (4 'no imagery' files skipped)
# Portland: 193 usable images found (1 'no imagery' files skipped)
# Oakland: 147 usable images found (5 'no imagery' files skipped)
# Dallas: 188 usable images found (1 'no imagery' files skipped)
# Philadelphiae: 193 usable images found (3 'no imagery' files skipped)
# Mesa: 111 usable images found (34 'no imagery' files skipped)
# Denveri: 171 usable images found (14 'no imagery' files skipped)
# Houston: 187 usable images found (4 'no imagery' files skipped)
# San Jose: 185 usable images found (10 'no imagery' files skipped)
# Raleigh: 188 usable images found (8 'no imagery' files skipped)
# Albuquerque: 170 usable images found (9 'no imagery' files skipped)
# Columbus: 186 usable images found (4 'no imagery' files skipped)
# Milwaukee: 189 usable images found (2 'no imagery' files skipped)
# El Paso: 93 usable images found (12 'no imagery' files skipped)
# Louisvillel: 140 usable images found (13 'no imagery' files skipped)
# Atlanta: 175 usable images found (9 'no imagery' files skipped)
# Fresno: 155 usable images found (3 'no imagery' files skipped)
# Tulsa: 170 usable images found (2 'no imagery' files skipped)
# Nashvillej: 171 usable images found (14 'no imagery' files skipped)
# New Yorkd: 190 usable images found (0 'no imagery' files skipped)
# Fort Worth: 136 usable images found (2 'no imagery' files skipped)
# Tampa: 194 usable images found (2 'no imagery' files skipped)
# Miami: 192 usable images found (2 'no imagery' files skipped)
# Tucson: 54 usable images found (26 'no imagery' files skipped)
# Washingtonk: 82 usable images found (0 'no imagery' files skipped)
# Boston: 62 usable images found (9 'no imagery' files skipped)
# San Diego: 124 usable images found (7 'no imagery' files skipped)
# Virginia Beachm: 8 usable images found (7 'no imagery' files skipped)
#
# Processing images with augmentations...
#
# Processing San Franciscoh...
#
# Processing Chicago...
#
# Processing Baltimorem...
#
# Processing Sacramento...
#
# Processing Austin...
#
# Processing Memphis...
#
# Processing Phoenix...
#
# Processing Detroit...
#
# Processing Minneapolis...
#
# Processing Omaha...
#
# Processing Kansas City...
#
# Processing Colorado Springs...
#
# Processing Indianapolisg...
#
# Processing Charlotte...
#
# Processing Las Vegas...
#
# Processing Seattle...
#
# Processing San Antonio...
#
# Processing Wichita...
#
# Processing Long Beach...
#
# Processing Los Angeles...
#
# Processing Oklahoma City...
#
# Processing Bakersfield...
#
# Processing Portland...
#
# Processing Oakland...
#
# Processing Dallas...
#
# Processing Philadelphiae...
#
# Processing Mesa...
#
# Processing Denveri...
#
# Processing Jacksonvillef...
#
# Processing Houston...
#
# Processing San Jose...
#
# Processing Raleigh...
#
# Processing Albuquerque...
#
# Processing Columbus...
#
# Processing Milwaukee...
#
# Processing Louisvillel...
#
# Processing Atlanta...
#
# Processing Fresno...
#
# Processing Nashvillej...
#
# Processing New Yorkd...
#
# Processing Fort Worth...
#
# Processing Tampa...
#
# Processing Tulsa...
#
# Processing Miami...
#
# Processing Tucson...
#
# Processing Washingtonk...
#
# Processing Boston...
#
# Processing San Diego...
#
# Processing El Paso...
#
# Processing Virginia Beachm...
#
# Final Processing Statistics:
# ----------------------------------------------------------------------------------------------------
# City                 Original Files  No Imagery      Processed    Augmented    Errors
# ----------------------------------------------------------------------------------------------------
# San Franciscoh       193             1               193          1544         0
# Chicago              165             25              165          1320         0
# Baltimorem           101             1               101          808          0
# Sacramento           176             3               176          1408         0
# Jacksonvillef        171             7               171          1368         0
# Austin               177             8               177          1416         0
# Memphis              179             8               179          1432         0
# Phoenix              165             15              165          1320         0
# Detroit              177             6               177          1416         0
# Minneapolis          193             3               193          1544         0
# Omaha                179             14              179          1432         0
# Kansas City          169             8               169          1352         0
# Colorado Springs     162             6               162          1296         0
# Indianapolisg        185             13              185          1480         0
# Charlotte            191             0               191          1528         0
# Las Vegas            163             32              163          1304         0
# Seattle              176             0               176          1408         0
# San Antonio          198             1               198          1584         0
# Wichita              157             2               157          1256         0
# Long Beach           163             5               163          1304         0
# Los Angeles          185             4               185          1480         0
# Oklahoma City        169             4               169          1352         0
# Bakersfield          180             4               180          1440         0
# Portland             193             1               193          1544         0
# Oakland              147             5               147          1176         0
# Dallas               188             1               188          1504         0
# Philadelphiae        193             3               193          1544         0
# Mesa                 111             34              111          888          0
# Denveri              171             14              171          1368         0
# Houston              187             4               187          1496         0
# San Jose             185             10              185          1480         0
# Raleigh              188             8               188          1504         0
# Albuquerque          170             9               170          1360         0
# Columbus             186             4               186          1488         0
# Milwaukee            189             2               189          1512         0
# El Paso              93              12              93           744          0
# Louisvillel          140             13              140          1120         0
# Atlanta              175             9               175          1400         0
# Fresno               155             3               155          1240         0
# Tulsa                170             2               170          1360         0
# Nashvillej           171             14              171          1368         0
# New Yorkd            190             0               190          1520         0
# Fort Worth           136             2               136          1088         0
# Tampa                194             2               194          1552         0
# Miami                192             2               192          1536         0
# Tucson               54              26              54           432          0
# Washingtonk          82              0               82           656          0
# Boston               62              9               62           496          0
# San Diego            124             7               124          992          0
# Virginia Beachm      8               7               8            64           0
#
# Verifying final image counts per city...
# San Franciscoh: 1737 total processed files
# Chicago: 1485 total processed files
# Baltimorem: 909 total processed files
# Sacramento: 1584 total processed files
# Austin: 1593 total processed files
# Memphis: 1611 total processed files
# Phoenix: 1485 total processed files
# Detroit: 1593 total processed files
# Minneapolis: 1737 total processed files
# Omaha: 1611 total processed files
# Kansas City: 1521 total processed files
# Colorado Springs: 1458 total processed files
# Indianapolisg: 1665 total processed files
# Charlotte: 1719 total processed files
# Las Vegas: 1467 total processed files
# Seattle: 1584 total processed files
# San Antonio: 1782 total processed files
# Wichita: 1413 total processed files
# Long Beach: 1467 total processed files
# Los Angeles: 1665 total processed files
# Oklahoma City: 1521 total processed files
# Bakersfield: 1620 total processed files
# Portland: 1737 total processed files
# Oakland: 1323 total processed files
# Dallas: 1692 total processed files
# Philadelphiae: 1737 total processed files
# Mesa: 999 total processed files
# Denveri: 1539 total processed files
# Jacksonvillef: 1539 total processed files
# Houston: 1683 total processed files
# San Jose: 1665 total processed files
# Raleigh: 1692 total processed files
# Albuquerque: 1530 total processed files
# Columbus: 1674 total processed files
# Milwaukee: 1701 total processed files
# Louisvillel: 1260 total processed files
# Atlanta: 1575 total processed files
# Fresno: 1395 total processed files
# Nashvillej: 1539 total processed files
# New Yorkd: 1710 total processed files
# Fort Worth: 1224 total processed files
# Tampa: 1746 total processed files
# Tulsa: 1530 total processed files
# Miami: 1728 total processed files
# Tucson: 486 total processed files
# Washingtonk: 738 total processed files
# Boston: 558 total processed files
# San Diego: 1116 total processed files
# El Paso: 837 total processed files
# Virginia Beachm: 72 total processed files
#
# Processing complete. All images converted, augmented, and saved to city-specific folders.
